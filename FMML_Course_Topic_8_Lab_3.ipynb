# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajaysigireddy/FMML_COURSE_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-14 11:07:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   333MB/s    in 0.2s
#
# 2023-05-14 11:07:58 (333 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 384    1709.05870v1  In this paper we introduce ZhuSuan, a python p...  stat
# 23063  1803.03432v1  We propose practical extensions to Bayesian op...  stat
# 3738   1606.01855v1  We introduce Bayesian Poisson Tucker decomposi...  stat
# 5203    1201.0959v1  Functional data analysis involves data describ...  stat
# 18455   1011.1660v1  In this paper, a new reinforcement learning ap...    cs
# ...             ...                                                ...   ...
# 7279   1711.06795v1  Most multi-class classifiers make their predic...  stat
# 37913   1110.4304v3  Echo state network (ESN) is viewed as a tempor...  stat
# 31534  1803.06152v1  We address the problem of jointly learning vis...    cs
# 15539  1508.07909v5  Neural machine translation (NMT) models typica...    cs
# 1792   1610.03035v6  We present the Latent Sequence Decompositions ...  stat
#
#                                                    title  year  \
# 384        ZhuSuan: A Library for Bayesian Deep Learning  2017
# 23063         Bayesian Optimization for Dynamic Problems  2018
# 3738   Bayesian Poisson Tucker Decomposition for Lear...  2016
# 5203   Constrained variable clustering and the best b...  2012
# 18455  Reinforcement Learning Based on Active Learnin...  2010
# ...                                                  ...   ...
# 7279   Prediction Scores as a Window into Classifier ...  2017
# 37913  Readouts for Echo-state Networks Built using L...  2011
# 31534  Object Captioning and Retrieval with Natural L...  2018
# 15539  Neural Machine Translation of Rare Words with ...  2015
# 1792                      Latent Sequence Decompositions  2016
#
#                                                 keywords
# 384    [introduce, probabilistic, programming, compli...
# 23063  [practical, extensions, optimization, objectiv...
# 3738   [introduce, decomposition, interaction, intera...
# 5203   [functional, described, functions, variables, ...
# 18455  [reinforcement, expresses, combination, single...
# ...                                                  ...
# 7279   [classifiers, prediction, selecting, analyzing...
# 37913  [orthogonal, expansion, parameters, expansions...
# 31534  [understand, descriptions, understanding, arch...
# 15539  [translation, typically, vocabulary, translati...
# 1792   [decompositions, framework, decomposes, sequen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 384      [introduce, probabilistic, programming, compli...
# 23063    [practical, extensions, optimization, objectiv...
# 3738     [introduce, decomposition, interaction, intera...
# 5203     [functional, described, functions, variables, ...
# 18455    [reinforcement, expresses, combination, single...
#                                ...
# 9407     [unsupervised, technique, biclustering, multim...
# 35755    [addresses, measurement, inference, highlights...
# 7949     [introduce, convolutional, recurrent, advantag...
# 21667    [theoretical, statistical, computational, prop...
# 5365     [introduce, estimation, calculates, datapoint,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8873 words.
# Out of those 4584 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e5f929a0-883e-4669-9c00-0e7a28626ff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5f929a0-883e-4669-9c00-0e7a28626ff5")) {                    Plotly.newPlot(                        "e5f929a0-883e-4669-9c00-0e7a28626ff5",                        [{"x":["tensorflow","traditional","generative","illustrate","hierarchical","supervised","deterministic","inference","variational","regression","including","supporting","programming","introduce","libraries","advantages","probabilistic","complimentary","recurrent","functions","optimization","exploiting","evaluations","synthetic","technique","spatiotemporal","extensions","instances","information","correlations","determines","available","appropriate","practical","objective","temporally","performance","relations","structure","discovers","memberships","interpretable","predictive","interaction","efficient","demonstrate","communities","knowledge","community","decomposition","international","overlapping","algorithm","clustering","dimensional","simplification","functional","regularity","constrained","representation","polynomial","variables","contiguity","complexity","described","piecewise","redundancy","individual","constraint","difference","reasoning","predefined","intelligent","reinforcement","approximate","according","expresses","generalized","combination","guarantees","representations","algorithms","backpropagation","accelerated","immediately","architectures","forecaster","generalization","properties","implications","empirical","equivalent","selection","convolutional","convergence","theoretically","classical","applications","covariance","underlying","numerical","attention","corresponding","experiments","formulate","estimator","framework","outperforms","significantly","eigenvector","eigenvalue","orthogonal","encourages","estimation","sacrificing","extraction","eigenvectors","maximization","especially","resulting","iteratively","reformulation","symmetric","procrustes","estimating","explained","approaches","rectangular","orthogonality","distances","comparisons","automatic","presented","compactly","coordinates","vectorial","euclidean","straightforward","signature","fundamental","published","verification","comparison","signatures","experimental","authenticity","connected","segmentation","evaluated","unambiguous","sequences","following","definition","description","developed","associated","descriptions","discovery","structures","descriptors","effectiveness","generally","distinguished","elucidated","kolmogorov","intermediate","initially","complicated","restricted","searching","solomonoff","retraining","techniques","methodology","classification","computational","recognition","accommodate","incremental","requirements","previously","incrementally","comparable","polynomially","theoretic","different","hypotheses","dimensions","alternatives","heuristic","bandwidth","theoretical","increases","differentiate","decreasing","understanding","nonparametric","solutions","alternative","statistics"],"y":[5,184,114,75,102,201,34,198,59,119,256,19,129,328,11,88,139,1,142,238,336,83,47,140,251,14,54,108,667,29,15,291,79,128,150,15,889,96,312,6,1,36,60,73,428,561,17,328,60,61,15,22,791,146,190,10,29,11,66,346,60,119,0,263,63,16,12,122,99,61,115,18,53,129,138,100,6,83,133,70,229,626,27,14,14,112,1,108,194,24,157,66,180,398,112,40,106,445,26,122,68,167,137,601,53,25,529,261,252,7,5,16,15,224,11,130,12,39,124,157,40,5,31,0,63,10,445,5,4,33,31,191,208,8,14,5,38,32,12,87,37,43,134,9,394,4,95,229,151,4,107,89,41,80,189,100,33,51,127,47,212,73,9,1,3,34,22,34,48,31,2,9,363,67,524,289,390,18,27,50,125,16,93,2,48,737,23,44,21,59,10,154,59,6,11,167,19,152,107,61],"type":"bar"},{"x":["tensorflow","traditional","generative","illustrate" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4584,), (4584, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7858333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Eigenvectors</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unipartite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bipartite</span> <span style=''>and</span> <span style=''>directed</span> <span style=''>graph</span> <span style=''>cases</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>concise</span> <span style=''>tutorial</span> <span style=''>on</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>for</span> <span style=''>broad</span> <span style=''>spectrum</span> <span style=''>graphs</span> <span style=''>which</span> <span style=''>include</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unipartite</span> <span style=''>(undirected)</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bipartite</span> <span style=''>graph</span> <span style=''>and</span> <span style=''>directed</span> <span style=''>graph</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.31764705882352945);'>transform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bipartite</span> <span style=''>graph</span> <span style=''>and</span> <span style=''>directed</span> <span style=''>graph</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unipartite</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>allowing</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>treatment</span> <span style=''>to</span> <span style=''>all</span> <span style=''>cases</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bipartite</span> <span style=''>graph</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>relaxed</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>K</span> <span style=''>way</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>can</span> <span style=''>be</span> <span style=''>found</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>the</span> <span style=''>left</span> <span style=''>and</span> <span style=''>right</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvectors</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>gives</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>basis</span> <span style=''>for</span> <span style=''>K</span> <span style=''>way</span> <span style=''>spectral</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>literatures</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>solving</span> <span style=''>row</span> <span style=''>and</span> <span style=''>column</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MCMC</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variationally</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>form</span> <span style=''>a</span> <span style=''>core</span> <span style=''>part</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Considerable</span> <span style=''>research</span> <span style=''>effort</span> <span style=''>has</span> <span style=''>been</span> <span style=''>made</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attacking</span> <span style=''>three</span> <span style=''>issues</span> <span style=''>with</span> <span style=''>GP</span> <span style=''>models</span> <span style=''>how</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>when</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>data</span> <span style=''>is</span> <span style=''>large</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>is</span> <span style=''>not</span> <span style=''>Gaussian</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posteriors</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>these</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>which</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>in</span> <span style=''>support</span> <span style=''>of</span> <span style=''>the</span> <span style=''>function</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>otherwise</span> <span style=''>free</span> <span style=''>form</span> <span style=''>The</span> <span style=''>result</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Hybrid</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>a</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>over</span> <span style=''>the</span> <span style=''>function</span> <span style=''>values</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>with</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>Distance</span> <span style=''>and</span> <span style=''>Pearson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <br/><br/><span style=''>For</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>it</span> <span style=''>has</span> <span style=''>often</span> <span style=''>been</span> <span style=''>observed</span> <span style=''>that</span> <span style=''>z</span> <span style=''>score</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distances</span> <span style=''>far</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>unnormalized</span> <span style=''>variant</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>z</span> <span style=''>score</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>squared</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>Distance</span> <span style=''>is</span> <span style=''>in</span> <span style=''>fact</span> <span style=''>equal</span> <span style=''>to</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Pearson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>This</span> <span style=''>has</span> <span style=''>profound</span> <span style=''>impact</span> <span style=''>on</span> <span style=''>many</span> <span style=''>distance</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>sound</span> <span style=''>result</span> <span style=''>we</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>often</span> <span style=''>used</span> <span style=''>k</span> <span style=''>Means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>formally</span> <span style=''>needs</span> <span style=''>a</span> <span style=''>mod</span> <span style=''>ification</span> <span style=''>to</span> <span style=''>keep</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>as</span> <span style=''>Pearson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>strictly</span> <span style=''>valid</span> <span style='background-color:rgba(0, 255, 0, 0.4172661870503597);'>Experimental</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>in</span> <span style=''>many</span> <span style=''>cases</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>k</span> <span style=''>Means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Characterizing</span> <span style=''>Markov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Equivalence</span> <span style=''>Classes</span> <span style=''>for</span> <span style=''>Directed</span> <span style=''>Acyclic</span> <span style=''>Graphs</span> <span style=''>with</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>there</span> <span style=''>may</span> <span style=''>be</span> <span style=''>many</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>data</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>common</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>into</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>what</span> <span style=''>is</span> <span style=''>less</span> <span style=''>well</span> <span style=''>known</span> <span style=''>how</span> <span style=''>do</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>common</span> <span style=''>to</span> <span style=''>every</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>among</span> <span style=''>the</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>of</span> <span style=''>some</span> <span style=''>DAG</span> <span style=''>process</span> <span style=''>change</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ancestral</span> <span style=''>graphs</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>graphs</span> <span style=''>that</span> <span style=''>can</span> <span style=''>encode</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>that</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>DAG</span> <span style=''>models</span> <span style=''>with</span> <span style=''>latent</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orientation</span> <span style=''>rules</span> <span style=''>that</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1025)
# 	evaluation (0.09857142857142857)
# 	information (0.2382142857142857)
# 	architecture (0.08607142857142858)
# 	experimental (0.1407142857142857)
# 	segmentation (0.08178571428571428)
# 	detection (0.12392857142857143)
# 	different (0.26321428571428573)
# 	recognition (0.1392857142857143)
# 	convolutional (0.14214285714285715)
#
# Some Statistics words are:
# 	theoretical (0.1425)
# 	estimation (0.1695)
# 	stochastic (0.14)
# 	algorithm (0.374)
# 	variables (0.142)
# 	statistical (0.1615)
# 	distribution (0.1825)
# 	dimensional (0.177)
# 	regression (0.182)
# 	inference (0.2155)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5b1a4666-c78c-4480-8bbb-4cbc6b617911" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b1a4666-c78c-4480-8bbb-4cbc6b617911")) {                    Plotly.newPlot(                        "5b1a4666-c78c-4480-8bbb-4cbc6b617911",                        [{"x":["tensorflow","traditional","generative","illustrate","hierarchical","supervised","deterministic","inference","variational","regression","including","supporting","programming","introduce","libraries","advantages","probabilistic","complimentary","recurrent","functions","optimization","exploiting","evaluations","synthetic","technique","spatiotemporal","extensions","instances","information","correlations","determines","available","appropriate","practical","objective","temporally","performance","relations","structure","discovers","memberships","interpretable","predictive","interaction","efficient","demonstrate","communities","knowledge","community","decomposition","international","overlapping","algorithm","clustering","dimensional","simplification","functional","regularity","constrained","representation","polynomial","variables","contiguity","complexity","described","piecewise","redundancy","individual","constraint","difference","reasoning","predefined","intelligent","reinforcement","approximate","according","expresses","generalized","combination","guarantees","representations","algorithms","backpropagation","accelerated","immediately","architectures","forecaster","generalization","properties","implications","empirical","equivalent","selection","convolutional","convergence","theoretically","classical","applications","covariance","underlying","numerical","attention","corresponding","experiments","formulate","estimator","framework","outperforms","significantly","eigenvector","eigenvalue","orthogonal","encourages","estimation","sacrificing","extraction","eigenvectors","maximization","especially","resulting","iteratively","reformulation","symmetric","procrustes","estimating","explained","approaches","rectangular","orthogonality","distances","comparisons","automatic","presented","compactly","coordinates","vectorial","euclidean","straightforward","signature","fundamental","published","verification","comparison","signatures","experimental","authenticity","connected","segmentation","evaluated","unambiguous","sequences","following","definition","description","developed","associated","descriptions","discovery","structures","descriptors","effectiveness","generally","distinguished","elucidated","kolmogorov","intermediate","initially","complicated","restricted","searching","solomonoff","retraining","techniques","methodology","classification","computational","recognition","accommodate","incremental","requirements","previously","incrementally","comparable","polynomially","theoretic","different","hypotheses","dimensions","alternatives","heuristic","bandwidth","theoretical","increases","differentiate","decreasing","understanding","nonparametric","solutions","alternative","statistics","specifically","hypothesis","increasing","independence","explicitly","dimension","minimizes","negativity","classifiers","numerically","classifier","relaxation","approximations","misclassification","biological","investigated","potentially","connectivity","expression","generated","application","superposition","extension","incorporate","combining","narrowing","combinations","interpretability","complementary","revolutionize","transparent","understandable","distributions","translation","predictions","dimensionality","processing","transformation","transformations","separation","quantized","conditions","distributed","precision","coordinate","sufficient","experiment","literature","iteration","assumption","characterized","quantization ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	contiguity
# 	procrustes
# 	negativity
# 	narrowing
# 	sparsistent
# 	emphsparse
# 	looseness
# 	cybersecurity
# 	subsamples
# 	precautions
# 	uncharted
# 	elucidating
# 	discriminable
# 	precipitation
# 	underdamped
# 	unavoidably
# 	hydrology
# 	climatology
# 	phenotypes
# 	prognostic
# Some words which never appear in Statistics papers:
# 	authenticity
# 	unambiguous
# 	solomonoff
# 	allocated
# 	disregarded
# 	discarded
# 	hypothesize
# 	recognise
# 	smartphone
# 	handcraft
# 	projectors
# 	photometric
# 	projector
# 	spectrums
# 	densification
# 	professionals
# 	observers
# 	eyeglasses
# 	dangerous
# 	abstracting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068990915786889e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
